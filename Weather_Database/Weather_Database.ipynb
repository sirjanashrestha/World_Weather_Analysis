# %%
#import the dependencies
import pandas as pd
import random
import matplotlib.pyplot as plt
import numpy as np
import requests
import time
from datetime import datetime

from citipy import citipy
from config import weather_api_key

# %%
url="https://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="+weather_api_key

# %%
#Create a set of 2000 random latitudes and longitudes
lats=np.random.uniform(low=-90,high=90,size=2000)
lngs=np.random.uniform(low=-90,high=90,size=2000)
lats_lngs=zip(lats,lngs)
coordinates=list(lats_lngs)

# %%
#Get the nearest city
cities=[]

#identify nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city=(citipy.nearest_city(coordinate[0],coordinate[1]).city_name)
    
    #If the city is unique, add it to the cities list
    if city not in cities:
        cities.append(city)

#print city count to confirm sufficient count
len(cities)
# Out:
# 754

# %%
{'coord': {'lon': -71.0598, 'lat': 42.3584},
 'weather': [{'id': 803,
   'main': 'Clouds',
   'description': 'broken clouds',
   'icon': '04d'}],
 'base': 'stations',
 'main': {'temp': 76.21,
  'feels_like': 77,
  'temp_min': 70.95,
  'temp_max': 82.8,
  'pressure': 1016,
  'humidity': 74},
 'visibility': 10000,
 'wind': {'speed': 16.11, 'deg': 80},
 'clouds': {'all': 75},
 'dt': 1661617164,
 'sys': {'type': 2,
  'id': 2013408,
  'country': 'US',
  'sunrise': 1661594658,
  'sunset': 1661642860},
 'timezone': -14400,
 'id': 4930956,
 'name': 'Boston',
 'cod': 200}
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 76.21,
#   'feels_like': 77,
#   'temp_min': 70.95,
#   'temp_max': 82.8,
#   'pressure': 1016,
#   'humidity': 74},
#  'visibility': 10000,
#  'wind': {'speed': 16.11, 'deg': 80},
#  'clouds': {'all': 75},
#  'dt': 1661617164,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1661594658,
#   'sunset': 1661642860},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
#Create an empty list to hold the weather data
city_data=[]

#print the beginning of the logging
print("Beggining Data Retrieval       ")
print("_______________________________")

#Create counters
record_count=1
set_count=1

#Loop through list of cities and build city URL
for i, city in enumerate(cities):
    
    #Group cities in a sets of 50 for logging purposes
    if (i%50==0 and i>=50):
        set_count+=1
        record_count=1
        
    #create endpoint URL with each city
    city_url=url+"&q="+city.replace(" ","+")
    
    #Log the URL,record and set numbers and city
    print(f"Processing Record {record_count} of set {set_count}|{city}")
    
    #Add 1 to the record count
    record_count+=1
    
    #Run an API request for each of the cities
    try:
        #Parse the JSON and retrieve data
        city_weather=requests.get(city_url).json()

            #Parse the needed data
        city_lat=city_weather['coord']['lat']
        city_lng=city_weather['coord']['lon']
        city_max_temp=city_weather['main']['temp_max']
        city_humidity=city_weather['main']['humidity']
        city_clouds=city_weather['clouds']['all']
        city_wind=city_weather['wind']['speed']
        city_country=city_weather['sys']['country']
        city_description=city_weather['weather'][0]['description']

            #Append city information into city_data list
        city_data.append(
                            {"City":city.title(),
                           "Lat":city_lat,
                             "Lng":city_lng,
                            "Max Temp":city_max_temp,
                            "Humidity":city_humidity,
                        "Cloudiness":city_clouds,
                        "Wind Speed":city_wind,
                        "Country":city_country,
                        "Current Situation":city_description})
                       
                    
        #If an error is occured, skip the city
    except:
        print("City not found: SKIPPING....."+city)
        pass
                                                                         
#Indicate that Data loading is complete
print("_________________________________")                         
print("Data Retreival Complete          ")        
print("_________________________________")
# Out:
# Beggining Data Retrieval
# _______________________________
# Processing Record 1 of set 1|grand gaube
# Processing Record 2 of set 1|dikson
# Processing Record 3 of set 1|maralal
# Processing Record 4 of set 1|tasiilaq
# Processing Record 5 of set 1|sturgeon falls
# Processing Record 6 of set 1|durgapur
# Processing Record 7 of set 1|illoqqortoormiut
# City not found: SKIPPING.....illoqqortoormiut
# Processing Record 8 of set 1|ushuaia
# Processing Record 9 of set 1|bandarbeyla
# Processing Record 10 of set 1|mormugao
# Processing Record 11 of set 1|salinopolis
# Processing Record 12 of set 1|punta arenas
# Processing Record 13 of set 1|chuy
# Processing Record 14 of set 1|zambezi
# Processing Record 15 of set 1|olinda
# Processing Record 16 of set 1|panaba
# Processing Record 17 of set 1|saint-philippe
# Processing Record 18 of set 1|saint-georges
# Processing Record 19 of set 1|stornoway
# Processing Record 20 of set 1|umm lajj
# Processing Record 21 of set 1|cockburn town
# Processing Record 22 of set 1|busselton
# Processing Record 23 of set 1|bredasdorp
# Processing Record 24 of set 1|sokolka
# Processing Record 25 of set 1|bayreuth
# Processing Record 26 of set 1|boende
# Processing Record 27 of set 1|urumqi
# Processing Record 28 of set 1|omaruru
# Processing Record 29 of set 1|kharp
# Processing Record 30 of set 1|san ramon
# Processing Record 31 of set 1|araouane
# Processing Record 32 of set 1|codrington
# Processing Record 33 of set 1|belushya guba
# City not found: SKIPPING.....belushya guba
# Processing Record 34 of set 1|waddan
# Processing Record 35 of set 1|itaituba
# Processing Record 36 of set 1|kulhudhuffushi
# Processing Record 37 of set 1|iqaluit
# Processing Record 38 of set 1|san martin
# Processing Record 39 of set 1|cidreira
# Processing Record 40 of set 1|tsihombe
# City not found: SKIPPING.....tsihombe
# Processing Record 41 of set 1|hagen
# Processing Record 42 of set 1|boca do acre
# Processing Record 43 of set 1|longyearbyen
# Processing Record 44 of set 1|umm kaddadah
# Processing Record 45 of set 1|sassandra
# Processing Record 46 of set 1|amapa
# Processing Record 47 of set 1|qaanaaq
# Processing Record 48 of set 1|talcahuano
# Processing Record 49 of set 1|dujuma
# City not found: SKIPPING.....dujuma
# Processing Record 50 of set 1|kayerkan
# Processing Record 1 of set 2|upernavik
# Processing Record 2 of set 2|kargasok
# Processing Record 3 of set 2|iquitos
# Processing Record 4 of set 2|kargopol
# Processing Record 5 of set 2|lagoa
# Processing Record 6 of set 2|praia da vitoria
# Processing Record 7 of set 2|el faiyum
# City not found: SKIPPING.....el faiyum
# Processing Record 8 of set 2|san-pedro
# Processing Record 9 of set 2|taolanaro
# City not found: SKIPPING.....taolanaro
# Processing Record 10 of set 2|kresttsy
# Processing Record 11 of set 2|port alfred
# Processing Record 12 of set 2|cape town
# Processing Record 13 of set 2|sihora
# Processing Record 14 of set 2|dingle
# Processing Record 15 of set 2|kangaatsiaq
# Processing Record 16 of set 2|bambous virieux
# Processing Record 17 of set 2|jussara
# Processing Record 18 of set 2|arraial do cabo
# Processing Record 19 of set 2|brae
# Processing Record 20 of set 2|saint-pierre
# Processing Record 21 of set 2|kindu
# Processing Record 22 of set 2|amderma
# City not found: SKIPPING.....amderma
# Processing Record 23 of set 2|guaruja
# Processing Record 24 of set 2|hambantota
# Processing Record 25 of set 2|ambilobe
# Processing Record 26 of set 2|valparaiso
# Processing Record 27 of set 2|hermanus
# Processing Record 28 of set 2|samandag
# Processing Record 29 of set 2|georgetown
# Processing Record 30 of set 2|adwa
# Processing Record 31 of set 2|asosa
# Processing Record 32 of set 2|mahebourg
# Processing Record 33 of set 2|saveh
# Processing Record 34 of set 2|gamba
# Processing Record 35 of set 2|jamestown
# Processing Record 36 of set 2|sao filipe
# Processing Record 37 of set 2|asfi
# Processing Record 38 of set 2|jumla
# Processing Record 39 of set 2|fort abbas
# Processing Record 40 of set 2|ribeira grande
# Processing Record 41 of set 2|torbay
# Processing Record 42 of set 2|the valley
# Processing Record 43 of set 2|husavik
# Processing Record 44 of set 2|barinas
# Processing Record 45 of set 2|attawapiskat
# City not found: SKIPPING.....attawapiskat
# Processing Record 46 of set 2|port elizabeth
# Processing Record 47 of set 2|alta floresta
# Processing Record 48 of set 2|narsaq
# Processing Record 49 of set 2|sorland
# Processing Record 50 of set 2|laguna
# Processing Record 1 of set 3|agva
# City not found: SKIPPING.....agva
# Processing Record 2 of set 3|bumba
# Processing Record 3 of set 3|irbil
# Processing Record 4 of set 3|kasimov
# Processing Record 5 of set 3|narbonne
# Processing Record 6 of set 3|porto murtinho
# Processing Record 7 of set 3|kruisfontein
# Processing Record 8 of set 3|herat
# Processing Record 9 of set 3|hamilton
# Processing Record 10 of set 3|marzuq
# Processing Record 11 of set 3|zarand
# Processing Record 12 of set 3|jacobina
# Processing Record 13 of set 3|champua
# Processing Record 14 of set 3|vila franca do campo
# Processing Record 15 of set 3|paamiut
# Processing Record 16 of set 3|san luis
# Processing Record 17 of set 3|saint-augustin
# Processing Record 18 of set 3|castro
# Processing Record 19 of set 3|bodden town
# Processing Record 20 of set 3|jabinyanah
# Processing Record 21 of set 3|keti bandar
# Processing Record 22 of set 3|thinadhoo
# Processing Record 23 of set 3|burica
# City not found: SKIPPING.....burica
# Processing Record 24 of set 3|mossendjo
# Processing Record 25 of set 3|kpandu
# Processing Record 26 of set 3|lisakovsk
# Processing Record 27 of set 3|westport
# Processing Record 28 of set 3|boddam
# Processing Record 29 of set 3|kungsbacka
# Processing Record 30 of set 3|hithadhoo
# Processing Record 31 of set 3|bathsheba
# Processing Record 32 of set 3|nuevitas
# Processing Record 33 of set 3|luderitz
# Processing Record 34 of set 3|gravdal
# Processing Record 35 of set 3|east london
# Processing Record 36 of set 3|baijiantan
# Processing Record 37 of set 3|talnakh
# Processing Record 38 of set 3|saint-francois
# Processing Record 39 of set 3|rawson
# Processing Record 40 of set 3|cayenne
# Processing Record 41 of set 3|berlevag
# Processing Record 42 of set 3|krasnoselkup
# Processing Record 43 of set 3|mar del plata
# Processing Record 44 of set 3|touros
# Processing Record 45 of set 3|salalah
# Processing Record 46 of set 3|henties bay
# Processing Record 47 of set 3|jasper
# Processing Record 48 of set 3|roald
# Processing Record 49 of set 3|gazojak
# Processing Record 50 of set 3|saint-joseph
# Processing Record 1 of set 4|huarmey
# Processing Record 2 of set 4|atbasar
# Processing Record 3 of set 4|coihaique
# Processing Record 4 of set 4|apatity
# Processing Record 5 of set 4|beoumi
# Processing Record 6 of set 4|rassvet
# Processing Record 7 of set 4|clyde river
# Processing Record 8 of set 4|mumford
# Processing Record 9 of set 4|talara
# Processing Record 10 of set 4|nouadhibou
# Processing Record 11 of set 4|iguape
# Processing Record 12 of set 4|sokolovo
# Processing Record 13 of set 4|qarqin
# Processing Record 14 of set 4|ponta do sol
# Processing Record 15 of set 4|rocha
# Processing Record 16 of set 4|tabas
# Processing Record 17 of set 4|sovetskiy
# Processing Record 18 of set 4|tombouctou
# Processing Record 19 of set 4|gander
# Processing Record 20 of set 4|ous
# Processing Record 21 of set 4|kodino
# Processing Record 22 of set 4|souillac
# Processing Record 23 of set 4|albany
# Processing Record 24 of set 4|kutum
# Processing Record 25 of set 4|khromtau
# Processing Record 26 of set 4|sioux lookout
# Processing Record 27 of set 4|maniitsoq
# Processing Record 28 of set 4|guatire
# Processing Record 29 of set 4|oistins
# Processing Record 30 of set 4|vestmannaeyjar
# Processing Record 31 of set 4|lakselv
# Processing Record 32 of set 4|traiguen
# Processing Record 33 of set 4|ginir
# Processing Record 34 of set 4|richards bay
# Processing Record 35 of set 4|faya
# Processing Record 36 of set 4|muros
# Processing Record 37 of set 4|caravelas
# Processing Record 38 of set 4|victoria
# Processing Record 39 of set 4|villazon
# Processing Record 40 of set 4|dom pedro
# Processing Record 41 of set 4|santa maria
# Processing Record 42 of set 4|maldonado
# Processing Record 43 of set 4|sankheda
# Processing Record 44 of set 4|vardo
# Processing Record 45 of set 4|colares
# Processing Record 46 of set 4|dom pedrito
# Processing Record 47 of set 4|demirci
# Processing Record 48 of set 4|abu dhabi
# Processing Record 49 of set 4|kumi
# Processing Record 50 of set 4|beloha
# Processing Record 1 of set 5|malinovoye ozero
# Processing Record 2 of set 5|nargana
# Processing Record 3 of set 5|quatre cocos
# Processing Record 4 of set 5|havelock
# Processing Record 5 of set 5|puri
# Processing Record 6 of set 5|riyaq
# City not found: SKIPPING.....riyaq
# Processing Record 7 of set 5|abengourou
# Processing Record 8 of set 5|valdivia
# Processing Record 9 of set 5|acurenam
# Processing Record 10 of set 5|mogadishu
# Processing Record 11 of set 5|doctor pedro p. pena
# City not found: SKIPPING.....doctor pedro p. pena
# Processing Record 12 of set 5|marawi
# Processing Record 13 of set 5|gobabis
# Processing Record 14 of set 5|saint george
# Processing Record 15 of set 5|mayen
# Processing Record 16 of set 5|vila velha
# Processing Record 17 of set 5|carnarvon
# Processing Record 18 of set 5|chimbote
# Processing Record 19 of set 5|margate
# Processing Record 20 of set 5|barentsburg
# City not found: SKIPPING.....barentsburg
# Processing Record 21 of set 5|kletnya
# Processing Record 22 of set 5|antalaha
# Processing Record 23 of set 5|tokmak
# Processing Record 24 of set 5|umzimvubu
# City not found: SKIPPING.....umzimvubu
# Processing Record 25 of set 5|hazaribag
# Processing Record 26 of set 5|cartagena del chaira
# Processing Record 27 of set 5|sao felix do xingu
# Processing Record 28 of set 5|ilulissat
# Processing Record 29 of set 5|kincardine
# Processing Record 30 of set 5|klaksvik
# Processing Record 31 of set 5|nebbi
# Processing Record 32 of set 5|sao joao da barra
# Processing Record 33 of set 5|shubarkuduk
# Processing Record 34 of set 5|pizarro
# Processing Record 35 of set 5|svetlyy
# Processing Record 36 of set 5|itarema
# Processing Record 37 of set 5|bolungarvik
# City not found: SKIPPING.....bolungarvik
# Processing Record 38 of set 5|padang
# Processing Record 39 of set 5|raga
# Processing Record 40 of set 5|mehamn
# Processing Record 41 of set 5|pachino
# Processing Record 42 of set 5|pokhara
# Processing Record 43 of set 5|conde
# Processing Record 44 of set 5|mahanoro
# Processing Record 45 of set 5|rodrigues alves
# Processing Record 46 of set 5|huallanca
# Processing Record 47 of set 5|diego de almagro
# Processing Record 48 of set 5|kavaratti
# Processing Record 49 of set 5|maragogi
# Processing Record 50 of set 5|kamenka
# Processing Record 1 of set 6|bar harbor
# Processing Record 2 of set 6|kabinda
# Processing Record 3 of set 6|asmara
# Processing Record 4 of set 6|gubin
# Processing Record 5 of set 6|labelle
# Processing Record 6 of set 6|bosaso
# Processing Record 7 of set 6|kuche
# City not found: SKIPPING.....kuche
# Processing Record 8 of set 6|necochea
# Processing Record 9 of set 6|kangasala
# Processing Record 10 of set 6|presidencia roque saenz pena
# Processing Record 11 of set 6|jacareacanga
# Processing Record 12 of set 6|coulihaut
# City not found: SKIPPING.....coulihaut
# Processing Record 13 of set 6|llanes
# Processing Record 14 of set 6|urucui
# Processing Record 15 of set 6|puerto quijarro
# Processing Record 16 of set 6|najran
# Processing Record 17 of set 6|mazagao
# Processing Record 18 of set 6|mbandaka
# Processing Record 19 of set 6|mercedes
# Processing Record 20 of set 6|parabel
# Processing Record 21 of set 6|mulchen
# Processing Record 22 of set 6|paucartambo
# City not found: SKIPPING.....paucartambo
# Processing Record 23 of set 6|verkhnetulomskiy
# Processing Record 24 of set 6|saldanha
# Processing Record 25 of set 6|feijo
# Processing Record 26 of set 6|carutapera
# Processing Record 27 of set 6|sarapulka
# Processing Record 28 of set 6|pecanha
# Processing Record 29 of set 6|bredene
# Processing Record 30 of set 6|ikom
# Processing Record 31 of set 6|diamantino
# Processing Record 32 of set 6|kalmar
# Processing Record 33 of set 6|kantemirovka
# Processing Record 34 of set 6|namibe
# Processing Record 35 of set 6|bakchar
# Processing Record 36 of set 6|lebu
# Processing Record 37 of set 6|tignere
# Processing Record 38 of set 6|tapaua
# City not found: SKIPPING.....tapaua
# Processing Record 39 of set 6|coquimbo
# Processing Record 40 of set 6|andenes
# Processing Record 41 of set 6|remetea mare
# Processing Record 42 of set 6|thunder bay
# Processing Record 43 of set 6|aqtobe
# Processing Record 44 of set 6|tanout
# Processing Record 45 of set 6|fonte boa
# Processing Record 46 of set 6|maracaibo
# Processing Record 47 of set 6|saint-leu
# Processing Record 48 of set 6|surt
# Processing Record 49 of set 6|ostersund
# Processing Record 50 of set 6|walvis bay
# Processing Record 1 of set 7|konya
# Processing Record 2 of set 7|tazovskiy
# Processing Record 3 of set 7|los llanos de aridane
# Processing Record 4 of set 7|viedma
# Processing Record 5 of set 7|sambava
# Processing Record 6 of set 7|aquidauana
# Processing Record 7 of set 7|bocana de paiwas
# Processing Record 8 of set 7|pietarsaari
# Processing Record 9 of set 7|sarai
# Processing Record 10 of set 7|muisne
# Processing Record 11 of set 7|amboasary
# Processing Record 12 of set 7|macae
# Processing Record 13 of set 7|barraute
# Processing Record 14 of set 7|nytva
# Processing Record 15 of set 7|aksu
# Processing Record 16 of set 7|hilton head island
# Processing Record 17 of set 7|hofn
# Processing Record 18 of set 7|ostrovnoy
# Processing Record 19 of set 7|nantucket
# Processing Record 20 of set 7|berbera
# Processing Record 21 of set 7|camacha
# Processing Record 22 of set 7|saryagash
# Processing Record 23 of set 7|elizabeth city
# Processing Record 24 of set 7|turkistan
# Processing Record 25 of set 7|kjollefjord
# Processing Record 26 of set 7|nedjo
# Processing Record 27 of set 7|san antonio
# Processing Record 28 of set 7|pisco
# Processing Record 29 of set 7|kytmanovo
# Processing Record 30 of set 7|lindome
# Processing Record 31 of set 7|adre
# Processing Record 32 of set 7|qasigiannguit
# Processing Record 33 of set 7|goderich
# Processing Record 34 of set 7|barra do garcas
# Processing Record 35 of set 7|dalvik
# Processing Record 36 of set 7|aden
# Processing Record 37 of set 7|hun
# Processing Record 38 of set 7|medina
# Processing Record 39 of set 7|bengkulu
# Processing Record 40 of set 7|mitsamiouli
# Processing Record 41 of set 7|puerto ayora
# Processing Record 42 of set 7|porto novo
# Processing Record 43 of set 7|puerto el triunfo
# Processing Record 44 of set 7|praia
# Processing Record 45 of set 7|pozo colorado
# Processing Record 46 of set 7|sainte-anne-des-monts
# Processing Record 47 of set 7|fereydun kenar
# Processing Record 48 of set 7|krutikha
# Processing Record 49 of set 7|grindavik
# Processing Record 50 of set 7|rabo de peixe
# Processing Record 1 of set 8|mezen
# Processing Record 2 of set 8|naryan-mar
# Processing Record 3 of set 8|chincha alta
# Processing Record 4 of set 8|sur
# Processing Record 5 of set 8|rolim de moura
# City not found: SKIPPING.....rolim de moura
# Processing Record 6 of set 8|abu kamal
# Processing Record 7 of set 8|kudahuvadhoo
# Processing Record 8 of set 8|dzaoudzi
# Processing Record 9 of set 8|toliary
# City not found: SKIPPING.....toliary
# Processing Record 10 of set 8|mhlambanyatsi
# Processing Record 11 of set 8|ahar
# Processing Record 12 of set 8|filadelfia
# Processing Record 13 of set 8|birao
# Processing Record 14 of set 8|puerto baquerizo moreno
# Processing Record 15 of set 8|constantine
# Processing Record 16 of set 8|olkhovatka
# Processing Record 17 of set 8|gudivada
# Processing Record 18 of set 8|remetea
# Processing Record 19 of set 8|sokolo
# Processing Record 20 of set 8|lukovetskiy
# Processing Record 21 of set 8|amudat
# Processing Record 22 of set 8|gazli
# Processing Record 23 of set 8|maceio
# Processing Record 24 of set 8|becerril
# Processing Record 25 of set 8|sandnessjoen
# Processing Record 26 of set 8|mayumba
# Processing Record 27 of set 8|grand river south east
# City not found: SKIPPING.....grand river south east
# Processing Record 28 of set 8|shchelyayur
# City not found: SKIPPING.....shchelyayur
# Processing Record 29 of set 8|panama city
# Processing Record 30 of set 8|abatskoye
# Processing Record 31 of set 8|baghdad
# Processing Record 32 of set 8|korla
# Processing Record 33 of set 8|sisimiut
# Processing Record 34 of set 8|saurimo
# Processing Record 35 of set 8|sedelnikovo
# City not found: SKIPPING.....sedelnikovo
# Processing Record 36 of set 8|luena
# Processing Record 37 of set 8|nuuk
# Processing Record 38 of set 8|taoudenni
# Processing Record 39 of set 8|hobyo
# Processing Record 40 of set 8|meulaboh
# Processing Record 41 of set 8|koutiala
# Processing Record 42 of set 8|tome-acu
# City not found: SKIPPING.....tome-acu
# Processing Record 43 of set 8|nanortalik
# Processing Record 44 of set 8|banepa
# Processing Record 45 of set 8|prainha
# Processing Record 46 of set 8|bull savanna
# Processing Record 47 of set 8|asyut
# Processing Record 48 of set 8|kasempa
# Processing Record 49 of set 8|padre bernardo
# Processing Record 50 of set 8|isabela
# Processing Record 1 of set 9|gunjur
# Processing Record 2 of set 9|ribeira brava
# Processing Record 3 of set 9|moussoro
# Processing Record 4 of set 9|lujan
# Processing Record 5 of set 9|calvinia
# Processing Record 6 of set 9|owerri
# Processing Record 7 of set 9|moose factory
# Processing Record 8 of set 9|vallenar
# Processing Record 9 of set 9|maunabo
# Processing Record 10 of set 9|santiago del estero
# Processing Record 11 of set 9|matagami
# Processing Record 12 of set 9|san cristobal
# Processing Record 13 of set 9|stara vyzhivka
# Processing Record 14 of set 9|el monte
# Processing Record 15 of set 9|ilhabela
# Processing Record 16 of set 9|igarka
# Processing Record 17 of set 9|grande-riviere
# City not found: SKIPPING.....grande-riviere
# Processing Record 18 of set 9|oktyabrskiy
# Processing Record 19 of set 9|lagdo
# Processing Record 20 of set 9|belmonte
# Processing Record 21 of set 9|axim
# Processing Record 22 of set 9|hearst
# Processing Record 23 of set 9|ust-tsilma
# Processing Record 24 of set 9|lucea
# Processing Record 25 of set 9|havre-saint-pierre
# Processing Record 26 of set 9|gambela
# Processing Record 27 of set 9|palma soriano
# Processing Record 28 of set 9|ponta delgada
# Processing Record 29 of set 9|sao marcos
# Processing Record 30 of set 9|pangnirtung
# Processing Record 31 of set 9|san andres
# Processing Record 32 of set 9|soyo
# Processing Record 33 of set 9|dolores
# Processing Record 34 of set 9|ormara
# Processing Record 35 of set 9|dosso
# Processing Record 36 of set 9|salvador
# Processing Record 37 of set 9|pravia
# Processing Record 38 of set 9|umea
# Processing Record 39 of set 9|takoradi
# Processing Record 40 of set 9|velsk
# Processing Record 41 of set 9|cabedelo
# Processing Record 42 of set 9|chicama
# Processing Record 43 of set 9|palaiokhora
# City not found: SKIPPING.....palaiokhora
# Processing Record 44 of set 9|mecca
# Processing Record 45 of set 9|beira
# Processing Record 46 of set 9|tokonou
# Processing Record 47 of set 9|kribi
# Processing Record 48 of set 9|kostomuksha
# Processing Record 49 of set 9|argelia
# Processing Record 50 of set 9|sharkan
# Processing Record 1 of set 10|grootfontein
# Processing Record 2 of set 10|agadir
# Processing Record 3 of set 10|ciudad bolivar
# Processing Record 4 of set 10|pangody
# Processing Record 5 of set 10|zastavna
# Processing Record 6 of set 10|guayaramerin
# Processing Record 7 of set 10|mora
# Processing Record 8 of set 10|wageningen
# Processing Record 9 of set 10|tumannyy
# City not found: SKIPPING.....tumannyy
# Processing Record 10 of set 10|ugoofaaru
# Processing Record 11 of set 10|sarnia
# Processing Record 12 of set 10|lewisporte
# Processing Record 13 of set 10|jalingo
# Processing Record 14 of set 10|abonnema
# Processing Record 15 of set 10|sao jose da coroa grande
# Processing Record 16 of set 10|corrientes
# Processing Record 17 of set 10|luau
# Processing Record 18 of set 10|niono
# Processing Record 19 of set 10|locri
# Processing Record 20 of set 10|dzhusaly
# City not found: SKIPPING.....dzhusaly
# Processing Record 21 of set 10|narasapur
# Processing Record 22 of set 10|laredo
# Processing Record 23 of set 10|eirunepe
# Processing Record 24 of set 10|camapua
# Processing Record 25 of set 10|malindi
# Processing Record 26 of set 10|atar
# Processing Record 27 of set 10|rio grande
# Processing Record 28 of set 10|rauma
# Processing Record 29 of set 10|kharabali
# Processing Record 30 of set 10|conselheiro lafaiete
# Processing Record 31 of set 10|nouakchott
# Processing Record 32 of set 10|yenotayevka
# Processing Record 33 of set 10|micheweni
# Processing Record 34 of set 10|chalus
# Processing Record 35 of set 10|strezhevoy
# Processing Record 36 of set 10|karasjok
# Processing Record 37 of set 10|severskaya
# Processing Record 38 of set 10|pedasi
# Processing Record 39 of set 10|ituango
# Processing Record 40 of set 10|harper
# Processing Record 41 of set 10|birjand
# Processing Record 42 of set 10|arequipa
# Processing Record 43 of set 10|san rafael del sur
# Processing Record 44 of set 10|ballitoville
# Processing Record 45 of set 10|bucsa
# Processing Record 46 of set 10|cravo norte
# Processing Record 47 of set 10|aksarka
# Processing Record 48 of set 10|snihurivka
# Processing Record 49 of set 10|opuwo
# Processing Record 50 of set 10|mahajanga
# Processing Record 1 of set 11|angra
# City not found: SKIPPING.....angra
# Processing Record 2 of set 11|yarada
# Processing Record 3 of set 11|samur
# Processing Record 4 of set 11|markapur
# Processing Record 5 of set 11|bayaguana
# Processing Record 6 of set 11|urdzhar
# City not found: SKIPPING.....urdzhar
# Processing Record 7 of set 11|teguise
# Processing Record 8 of set 11|iquique
# Processing Record 9 of set 11|mrirt
# City not found: SKIPPING.....mrirt
# Processing Record 10 of set 11|kjopsvik
# Processing Record 11 of set 11|lyndon
# Processing Record 12 of set 11|halifax
# Processing Record 13 of set 11|lola
# Processing Record 14 of set 11|pershotravneve
# Processing Record 15 of set 11|gornyak
# Processing Record 16 of set 11|bonavista
# Processing Record 17 of set 11|lagos
# Processing Record 18 of set 11|toftir
# City not found: SKIPPING.....toftir
# Processing Record 19 of set 11|tubruq
# City not found: SKIPPING.....tubruq
# Processing Record 20 of set 11|mikhaylovsk
# Processing Record 21 of set 11|oranjestad
# Processing Record 22 of set 11|irece
# Processing Record 23 of set 11|ust-kulom
# Processing Record 24 of set 11|finote selam
# Processing Record 25 of set 11|toms river
# Processing Record 26 of set 11|arlit
# Processing Record 27 of set 11|dakar
# Processing Record 28 of set 11|belyy yar
# Processing Record 29 of set 11|bage
# Processing Record 30 of set 11|lima
# Processing Record 31 of set 11|sistranda
# Processing Record 32 of set 11|matara
# Processing Record 33 of set 11|sao lourenco do sul
# Processing Record 34 of set 11|lucapa
# Processing Record 35 of set 11|cobija
# Processing Record 36 of set 11|santo andre
# Processing Record 37 of set 11|sinkat
# City not found: SKIPPING.....sinkat
# Processing Record 38 of set 11|peniche
# Processing Record 39 of set 11|azimur
# City not found: SKIPPING.....azimur
# Processing Record 40 of set 11|bani
# Processing Record 41 of set 11|kamennogorsk
# Processing Record 42 of set 11|riyadh
# Processing Record 43 of set 11|ornskoldsvik
# Processing Record 44 of set 11|malanje
# Processing Record 45 of set 11|mount pleasant
# Processing Record 46 of set 11|luangwa
# Processing Record 47 of set 11|adrian
# Processing Record 48 of set 11|rapar
# Processing Record 49 of set 11|ozgon
# City not found: SKIPPING.....ozgon
# Processing Record 50 of set 11|huntsville
# Processing Record 1 of set 12|kasimbazar
# City not found: SKIPPING.....kasimbazar
# Processing Record 2 of set 12|ariquemes
# Processing Record 3 of set 12|riberalta
# Processing Record 4 of set 12|khoy
# Processing Record 5 of set 12|tarudant
# City not found: SKIPPING.....tarudant
# Processing Record 6 of set 12|ancud
# Processing Record 7 of set 12|skjervoy
# Processing Record 8 of set 12|mananjary
# Processing Record 9 of set 12|simplicio mendes
# Processing Record 10 of set 12|banikoara
# Processing Record 11 of set 12|mpophomeni
# Processing Record 12 of set 12|san pedro
# Processing Record 13 of set 12|wajir
# Processing Record 14 of set 12|yabelo
# Processing Record 15 of set 12|sukhobezvodnoye
# Processing Record 16 of set 12|xuddur
# Processing Record 17 of set 12|novhorodka
# Processing Record 18 of set 12|rota
# Processing Record 19 of set 12|chardara
# Processing Record 20 of set 12|bekovo
# Processing Record 21 of set 12|huntington
# Processing Record 22 of set 12|boda
# Processing Record 23 of set 12|lodja
# Processing Record 24 of set 12|shilovo
# Processing Record 25 of set 12|selma
# Processing Record 26 of set 12|wawa
# Processing Record 27 of set 12|mullaitivu
# City not found: SKIPPING.....mullaitivu
# Processing Record 28 of set 12|sabla
# Processing Record 29 of set 12|tiznit
# Processing Record 30 of set 12|chimore
# Processing Record 31 of set 12|samfya
# Processing Record 32 of set 12|banswara
# Processing Record 33 of set 12|odweyne
# Processing Record 34 of set 12|koslan
# Processing Record 35 of set 12|bubaque
# Processing Record 36 of set 12|sao miguel do araguaia
# Processing Record 37 of set 12|saint pete beach
# Processing Record 38 of set 12|urfa
# City not found: SKIPPING.....urfa
# Processing Record 39 of set 12|louisbourg
# City not found: SKIPPING.....louisbourg
# Processing Record 40 of set 12|serenje
# Processing Record 41 of set 12|luba
# Processing Record 42 of set 12|kidal
# Processing Record 43 of set 12|vestmanna
# Processing Record 44 of set 12|vagay
# Processing Record 45 of set 12|bogo
# Processing Record 46 of set 12|cassilandia
# Processing Record 47 of set 12|methoni
# Processing Record 48 of set 12|novyy buyan
# Processing Record 49 of set 12|graaff-reinet
# Processing Record 50 of set 12|salinas
# Processing Record 1 of set 13|mmabatho
# Processing Record 2 of set 13|jalu
# Processing Record 3 of set 13|constitucion
# Processing Record 4 of set 13|yenagoa
# Processing Record 5 of set 13|adrar
# Processing Record 6 of set 13|rio gallegos
# Processing Record 7 of set 13|safranbolu
# Processing Record 8 of set 13|abu samrah
# Processing Record 9 of set 13|kaoma
# Processing Record 10 of set 13|letlhakane
# Processing Record 11 of set 13|manicore
# Processing Record 12 of set 13|rajapur
# Processing Record 13 of set 13|nizwa
# Processing Record 14 of set 13|mabaruma
# Processing Record 15 of set 13|tuggurt
# City not found: SKIPPING.....tuggurt
# Processing Record 16 of set 13|santiago de cao
# Processing Record 17 of set 13|sura mica
# Processing Record 18 of set 13|belluno
# Processing Record 19 of set 13|catamarca
# Processing Record 20 of set 13|sarh
# Processing Record 21 of set 13|bonfim
# Processing Record 22 of set 13|gazanjyk
# Processing Record 23 of set 13|varnavino
# Processing Record 24 of set 13|bam
# Processing Record 25 of set 13|malwan
# City not found: SKIPPING.....malwan
# Processing Record 26 of set 13|kyle of lochalsh
# City not found: SKIPPING.....kyle of lochalsh
# Processing Record 27 of set 13|gap
# Processing Record 28 of set 13|san juan de los morros
# Processing Record 29 of set 13|conceicao do mato dentro
# Processing Record 30 of set 13|doka
# Processing Record 31 of set 13|anloga
# Processing Record 32 of set 13|felidhoo
# City not found: SKIPPING.....felidhoo
# Processing Record 33 of set 13|njombe
# Processing Record 34 of set 13|yar-sale
# Processing Record 35 of set 13|gori
# Processing Record 36 of set 13|bahia blanca
# Processing Record 37 of set 13|solwezi
# Processing Record 38 of set 13|sabzevar
# Processing Record 39 of set 13|sao gabriel da cachoeira
# Processing Record 40 of set 13|ocean city
# Processing Record 41 of set 13|carinhanha
# Processing Record 42 of set 13|nacala
# Processing Record 43 of set 13|pirot
# Processing Record 44 of set 13|lokoja
# Processing Record 45 of set 13|moyale
# Processing Record 46 of set 13|skelleftea
# Processing Record 47 of set 13|santa marta
# Processing Record 48 of set 13|mindelo
# Processing Record 49 of set 13|yeletskiy
# City not found: SKIPPING.....yeletskiy
# Processing Record 50 of set 13|wilmington
# Processing Record 1 of set 14|omboue
# Processing Record 2 of set 14|mahaicony
# City not found: SKIPPING.....mahaicony
# Processing Record 3 of set 14|rey bouba
# Processing Record 4 of set 14|muromtsevo
# Processing Record 5 of set 14|copiapo
# Processing Record 6 of set 14|kuusamo
# Processing Record 7 of set 14|madimba
# Processing Record 8 of set 14|numi
# City not found: SKIPPING.....numi
# Processing Record 9 of set 14|bereda
# Processing Record 10 of set 14|ankazoabo
# Processing Record 11 of set 14|shieli
# Processing Record 12 of set 14|sabha
# Processing Record 13 of set 14|kilis
# Processing Record 14 of set 14|savonlinna
# Processing Record 15 of set 14|qaqortoq
# Processing Record 16 of set 14|road town
# Processing Record 17 of set 14|weligama
# Processing Record 18 of set 14|nurota
# Processing Record 19 of set 14|mitzic
# Processing Record 20 of set 14|sicuani
# Processing Record 21 of set 14|bogande
# Processing Record 22 of set 14|dossor
# Processing Record 23 of set 14|felipe carrillo puerto
# Processing Record 24 of set 14|vila do maio
# Processing Record 25 of set 14|jimma
# Processing Record 26 of set 14|port blair
# Processing Record 27 of set 14|coxim
# Processing Record 28 of set 14|sept-iles
# Processing Record 29 of set 14|lisala
# Processing Record 30 of set 14|port hawkesbury
# Processing Record 31 of set 14|kiruna
# Processing Record 32 of set 14|alghero
# Processing Record 33 of set 14|verkhnyaya sysert
# Processing Record 34 of set 14|chapais
# Processing Record 35 of set 14|manica
# Processing Record 36 of set 14|port-gentil
# Processing Record 37 of set 14|bom jesus
# Processing Record 38 of set 14|linhares
# Processing Record 39 of set 14|benghazi
# Processing Record 40 of set 14|miraflores
# Processing Record 41 of set 14|porbandar
# Processing Record 42 of set 14|amparafaravola
# Processing Record 43 of set 14|manyana
# Processing Record 44 of set 14|pointe-noire
# Processing Record 45 of set 14|mahdalynivka
# Processing Record 46 of set 14|gwanda
# Processing Record 47 of set 14|prado
# Processing Record 48 of set 14|santarem
# Processing Record 49 of set 14|tarko-sale
# Processing Record 50 of set 14|marv dasht
# City not found: SKIPPING.....marv dasht
# Processing Record 1 of set 15|batie
# Processing Record 2 of set 15|yurya
# City not found: SKIPPING.....yurya
# Processing Record 3 of set 15|vangaindrano
# Processing Record 4 of set 15|pinega
# Processing Record 5 of set 15|placido de castro
# Processing Record 6 of set 15|jega
# Processing Record 7 of set 15|voyskovitsy
# Processing Record 8 of set 15|bur gabo
# City not found: SKIPPING.....bur gabo
# Processing Record 9 of set 15|tandil
# Processing Record 10 of set 15|arrifes
# Processing Record 11 of set 15|camacupa
# Processing Record 12 of set 15|sinnamary
# Processing Record 13 of set 15|south venice
# Processing Record 14 of set 15|caceres
# Processing Record 15 of set 15|san jose
# Processing Record 16 of set 15|do rud
# City not found: SKIPPING.....do rud
# Processing Record 17 of set 15|vostochnyy
# Processing Record 18 of set 15|trelew
# Processing Record 19 of set 15|joshimath
# Processing Record 20 of set 15|synya
# Processing Record 21 of set 15|balykshi
# Processing Record 22 of set 15|calama
# Processing Record 23 of set 15|tres arroyos
# Processing Record 24 of set 15|at-bashi
# Processing Record 25 of set 15|portovelo
# Processing Record 26 of set 15|onverwacht
# Processing Record 27 of set 15|wattegama
# Processing Record 28 of set 15|aswan
# Processing Record 29 of set 15|ndele
# Processing Record 30 of set 15|sindand
# City not found: SKIPPING.....sindand
# Processing Record 31 of set 15|gorom-gorom
# Processing Record 32 of set 15|achisay
# City not found: SKIPPING.....achisay
# Processing Record 33 of set 15|altamira
# Processing Record 34 of set 15|alabaster
# Processing Record 35 of set 15|babanusah
# City not found: SKIPPING.....babanusah
# Processing Record 36 of set 15|turukhansk
# Processing Record 37 of set 15|plettenberg bay
# Processing Record 38 of set 15|sereflikochisar
# Processing Record 39 of set 15|khazar
# Processing Record 40 of set 15|kwale
# Processing Record 41 of set 15|cururupu
# Processing Record 42 of set 15|garbolovo
# Processing Record 43 of set 15|zabol
# Processing Record 44 of set 15|sokoto
# Processing Record 45 of set 15|conceicao do araguaia
# Processing Record 46 of set 15|loukhi
# Processing Record 47 of set 15|gat
# Processing Record 48 of set 15|easley
# Processing Record 49 of set 15|pangoa
# Processing Record 50 of set 15|paita
# Processing Record 1 of set 16|pimenta bueno
# Processing Record 2 of set 16|hualmay
# Processing Record 3 of set 16|riachao
# Processing Record 4 of set 16|correntina
# _________________________________
# Data Retreival Complete
# _________________________________

# %%
#create the array of dictionaries to panda dataframe
city_data_df=pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0     Grand Gaube -20.0064  57.6608     70.38        77           8
# 1          Dikson  73.5069  80.5464     18.07        89         100
# 2         Maralal   1.0968  36.6980     59.38        86          95
# 3        Tasiilaq  65.6145 -37.6368     37.56        99         100
# 4  Sturgeon Falls  46.3646 -79.9326     50.05        83          88
# 5        Durgapur  23.4833  87.3167     67.96        64           0
# 6         Ushuaia -54.8000 -68.3000     37.06        87         100
# 7     Bandarbeyla   9.4942  50.8122     76.71        75          24
# 8        Mormugao  15.4000  73.8000     76.26        78          40
# 9     Salinopolis  -0.6136 -47.3561     81.25        80          72
#
#    Wind Speed Country Current Situation
# 0        3.00      MU         clear sky
# 1        8.86      RU   overcast clouds
# 2        6.51      KE        light rain
# 3       13.47      GL     moderate rain
# 4        6.22      CA   overcast clouds
# 5        6.22      IN         clear sky
# 6       21.85      AR        light rain
# 7        8.81      SO        few clouds
# 8        4.61      IN  scattered clouds
# 9       14.92      BR     broken clouds

# %%
#Create the output file(CSV)
output_data_file="WeatherPy_Database.csv"

# Export the Weather database into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
